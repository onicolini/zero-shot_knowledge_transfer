# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn.functional as F
import numpy as np
import sys
from torchsummary import summary

from channel_wide_res_net import Channel_Wide_ResNet


'''
Function that loads the dataset and returns the data-loaders
'''
def getData(batch_size,test_batch_size,val_percentage):
    # Normalize the training set with data augmentation
    transform_train = transforms.Compose([ 
        torchvision.transforms.Resize(32),
        transforms.RandomHorizontalFlip(),
        torchvision.transforms.RandomRotation(20),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,)),
    ])
    
    # Normalize the test set same as training set without augmentation
    transform_test = transforms.Compose([ 
        torchvision.transforms.Resize(32),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,)),
    ])

    # Download/Load data
    full_training_data = torchvision.datasets.FashionMNIST('/home/test/data',train = True,transform=transform_train,download=True)  
    test_data = torchvision.datasets.FashionMNIST('/home/test/data',train = False,transform=transform_test,download=True)  

    # Create train and validation splits
    num_samples = len(full_training_data)
    training_samples = int((1-val_percentage)*num_samples+1)
    validation_samples = num_samples - training_samples
    training_data, validation_data = torch.utils.data.random_split(full_training_data, [training_samples, validation_samples])

    # Initialize dataloaders
    train_loader = torch.utils.data.DataLoader(training_data,batch_size=batch_size,shuffle=True, drop_last=True, num_workers = 4)
    val_loader = torch.utils.data.DataLoader(validation_data,batch_size=batch_size,shuffle=False, drop_last=False, num_workers = 2)
    test_loader = torch.utils.data.DataLoader(test_data,batch_size=test_batch_size,shuffle=False, drop_last=False, num_workers = 2)

    return train_loader, val_loader, test_loader

'''
Function to test that returns the loss per sample and the total accuracy
'''
def test(data_loader,net,cost_fun,device):
  
    net.eval()
    samples = 0.
    cumulative_loss = 0.
    cumulative_accuracy = 0.

    for batch_idx, (inputs,targets) in enumerate(data_loader):

        inputs = inputs.to(device)
        targets = targets.to(device)

        outputs = net(inputs)[0]
        loss = cost_fun(outputs,targets)

        # Metrics computation
        samples+=inputs.shape[0]
        cumulative_loss += loss.item()
        _, predicted = outputs.max(1)
        cumulative_accuracy += predicted.eq(targets).sum().item()

    return cumulative_loss/samples, cumulative_accuracy/samples*100

'''
Function to train the nework on the data for one epoch that returns the loss per sample and the total accuracy
'''
def train(data_loader,net,cost_fun,device,optimizer):
    
    net.train()
    samples = 0.
    cumulative_loss = 0.
    cumulative_accuracy = 0.

    for batch_idx, (inputs,targets) in enumerate(data_loader):
        inputs = inputs.to(device)
        targets = targets.to(device)

        outputs = net(inputs)[0]
        loss = cost_fun(outputs,targets)

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        # Metrics computation
        samples+=inputs.shape[0]
        cumulative_loss += loss.item()
        _, predicted = outputs.max(1)
        cumulative_accuracy += predicted.eq(targets).sum().item()

    return cumulative_loss/samples, cumulative_accuracy/samples*100

def main(epochs, batch_size, test_batch_size,val_percentage,lr,test_freq, net_depth, net_width):
    
    # Define cost function
    cost_function = torch.nn.CrossEntropyLoss()

    # Create the network: Wide_ResNet(depth, width, dropout, num_classes)
    net = Channel_Wide_ResNet(1,net_depth,net_width,0,10)
    net = net.to(device)
    #summary(net, input_size=(1, 28, 28))

    # Create the optimizer anche the learning rate scheduler
    optimizer = torch.optim.SGD(net.parameters(), lr=lr, momentum=0.9, weight_decay=5e-4)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, 
                    milestones=[int(epochs*0.3),int(epochs*0.6),int(epochs*0.8)], gamma=0.20)

    # Get the data
    train_loader, val_loader, test_loader = getData(batch_size,test_batch_size,val_percentage)
    
    save_filename = './Fashion-MNIST-teacher-' + str(net_depth) + '-' +  str(net_width) + '.pth'

    for e in range(epochs):
        net.train() 

        train_loss, train_accuracy = train(train_loader,net,cost_function,device,optimizer)

        val_loss, val_accuracy = test(val_loader,net,cost_function,device)
        
        scheduler.step()

        print('Epoch: {:d}:'.format(e+1))
        print('\t Training loss: \t {:.6f}, \t Training accuracy \t {:.2f}'.format(train_loss, train_accuracy))
        print('\t Validation loss: \t {:.6f},\t Validation accuracy \t {:.2f}'.format(val_loss, val_accuracy))
        
        if((e+1) % test_freq) == 0:
            test_loss, test_accuracy = test(test_loader,net,cost_function,device)
            torch.save(net.state_dict(), save_filename)
            print('Test loss: \t {:.6f}, \t \t Test accuracy \t {:.2f}'.format(test_loss, test_accuracy))

    print('After training:')
    train_loss, train_accuracy = test(train_loader,net,cost_function,device)
    val_loss, val_accuracy = test(val_loader,net,cost_function,device)
    test_loss, test_accuracy = test(test_loader,net,cost_function,device)

    print('\t Training loss: \t {:.6f}, \t Training accuracy \t {:.2f}'.format(train_loss, train_accuracy))
    print('\t Validation loss: \t {:.6f},\t Validation accuracy \t {:.2f}'.format(val_loss, val_accuracy))
    print('Test loss: \t {:.6f}, \t \t Test accuracy \t {:.2f}'.format(test_loss, test_accuracy))
    
    torch.save(net.state_dict(), save_filename)

    net2 = Channel_Wide_ResNet(1,net_depth,net_width,0,10)
    net2 = net.to(device)
    net2.load_state_dict(torch.load(save_filename))
    
    print('loaded net test:')
    test_loss, test_accuracy = test(test_loader,net2,cost_function,device)
    print('\t Test loss: \t {:.6f}, \t Test accuracy \t {:.2f}'.format(test_loss, test_accuracy))
    

# Parameters
epochs = 30
batch_size = 128
test_batch_size = 128
val_percentage = 0.05
lr = 0.1
test_freq = 5
device = 'cuda:0'
net_depth = 40
net_width = 2
    
main(epochs, batch_size, test_batch_size,val_percentage,lr,test_freq, net_depth, net_width)
# Out:
# 0.3%
# | Wide-Resnet 40x2
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to /home/test/data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100.0%
# Extracting /home/test/data/FashionMNIST/raw/train-images-idx3-ubyte.gz to /home/test/data/FashionMNIST/raw
# 111.0%
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to /home/test/data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# Extracting /home/test/data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to /home/test/data/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to /home/test/data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 159.1%
# Extracting /home/test/data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to /home/test/data/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to /home/test/data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# Extracting /home/test/data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to /home/test/data/FashionMNIST/raw
# Processing...
# Done!
# Epoch: 1:
# 	 Training loss: 	 0.005345, 	 Training accuracy 	 74.68
# 	 Validation loss: 	 0.004509,	 Validation accuracy 	 80.13
# Epoch: 2:
# 	 Training loss: 	 0.003285, 	 Training accuracy 	 84.61
# 	 Validation loss: 	 0.003138,	 Validation accuracy 	 85.50
# Epoch: 3:
# 	 Training loss: 	 0.002775, 	 Training accuracy 	 87.12
# 	 Validation loss: 	 0.004274,	 Validation accuracy 	 82.09
# Epoch: 4:
# 	 Training loss: 	 0.002544, 	 Training accuracy 	 88.23
# 	 Validation loss: 	 0.002875,	 Validation accuracy 	 86.66
# Epoch: 5:
# 	 Training loss: 	 0.002430, 	 Training accuracy 	 88.79
# 	 Validation loss: 	 0.015249,	 Validation accuracy 	 56.39
# Test loss: 	 0.013922, 	 	 Test accuracy 	 59.67
# Epoch: 6:
# 	 Training loss: 	 0.002351, 	 Training accuracy 	 89.11
# 	 Validation loss: 	 0.003180,	 Validation accuracy 	 85.60
# Epoch: 7:
# 	 Training loss: 	 0.002298, 	 Training accuracy 	 89.38
# 	 Validation loss: 	 0.002500,	 Validation accuracy 	 88.50
# Epoch: 8:
# 	 Training loss: 	 0.002283, 	 Training accuracy 	 89.38
# 	 Validation loss: 	 0.002439,	 Validation accuracy 	 88.73
# Epoch: 9:
# 	 Training loss: 	 0.002260, 	 Training accuracy 	 89.66
# 	 Validation loss: 	 0.002669,	 Validation accuracy 	 87.06
# Epoch: 10:
# 	 Training loss: 	 0.001751, 	 Training accuracy 	 91.89
# 	 Validation loss: 	 0.001761,	 Validation accuracy 	 91.50
# Test loss: 	 0.001790, 	 	 Test accuracy 	 91.76
# Epoch: 11:
# 	 Training loss: 	 0.001624, 	 Training accuracy 	 92.49
# 	 Validation loss: 	 0.001840,	 Validation accuracy 	 91.46
# Epoch: 12:
# 	 Training loss: 	 0.001583, 	 Training accuracy 	 92.78
# 	 Validation loss: 	 0.001884,	 Validation accuracy 	 91.83
# Epoch: 13:
# 	 Training loss: 	 0.001536, 	 Training accuracy 	 92.91
# 	 Validation loss: 	 0.006678,	 Validation accuracy 	 74.42
# Epoch: 14:
# 	 Training loss: 	 0.001523, 	 Training accuracy 	 92.91
# 	 Validation loss: 	 0.001706,	 Validation accuracy 	 92.23
# Epoch: 15:
# 	 Training loss: 	 0.001532, 	 Training accuracy 	 92.94
# 	 Validation loss: 	 0.001736,	 Validation accuracy 	 91.66
# Test loss: 	 0.001657, 	 	 Test accuracy 	 92.41
# Epoch: 16:
# 	 Training loss: 	 0.001496, 	 Training accuracy 	 93.09
# 	 Validation loss: 	 0.003487,	 Validation accuracy 	 84.73
# Epoch: 17:
# 	 Training loss: 	 0.001473, 	 Training accuracy 	 93.12
# 	 Validation loss: 	 0.001656,	 Validation accuracy 	 92.26
# Epoch: 18:
# 	 Training loss: 	 0.001482, 	 Training accuracy 	 93.10
# 	 Validation loss: 	 0.001942,	 Validation accuracy 	 91.10
# Epoch: 19:
# 	 Training loss: 	 0.001237, 	 Training accuracy 	 94.29
# 	 Validation loss: 	 0.001371,	 Validation accuracy 	 93.16
# Epoch: 20:
# 	 Training loss: 	 0.001136, 	 Training accuracy 	 94.76
# 	 Validation loss: 	 0.001392,	 Validation accuracy 	 93.96
# Test loss: 	 0.001464, 	 	 Test accuracy 	 93.68
# Epoch: 21:
# 	 Training loss: 	 0.001111, 	 Training accuracy 	 94.82
# 	 Validation loss: 	 0.001359,	 Validation accuracy 	 93.40
# Epoch: 22:
# 	 Training loss: 	 0.001081, 	 Training accuracy 	 94.99
# 	 Validation loss: 	 0.001399,	 Validation accuracy 	 93.66
# Epoch: 23:
# 	 Training loss: 	 0.001064, 	 Training accuracy 	 95.11
# 	 Validation loss: 	 0.001368,	 Validation accuracy 	 94.06
# Epoch: 24:
# 	 Training loss: 	 0.001045, 	 Training accuracy 	 95.23
# 	 Validation loss: 	 0.001352,	 Validation accuracy 	 93.50
# Epoch: 25:
# 	 Training loss: 	 0.000932, 	 Training accuracy 	 95.81
# 	 Validation loss: 	 0.001277,	 Validation accuracy 	 94.23
# Test loss: 	 0.001392, 	 	 Test accuracy 	 93.90
# Epoch: 26:
# 	 Training loss: 	 0.000915, 	 Training accuracy 	 95.78
# 	 Validation loss: 	 0.001297,	 Validation accuracy 	 93.80
# Epoch: 27:
# 	 Training loss: 	 0.000902, 	 Training accuracy 	 95.92
# 	 Validation loss: 	 0.001295,	 Validation accuracy 	 93.66
# Epoch: 28:
# 	 Training loss: 	 0.000894, 	 Training accuracy 	 95.93
# 	 Validation loss: 	 0.001300,	 Validation accuracy 	 94.23
# Epoch: 29:
# 	 Training loss: 	 0.000889, 	 Training accuracy 	 95.96
# 	 Validation loss: 	 0.001345,	 Validation accuracy 	 94.23
# Epoch: 30:
# 	 Training loss: 	 0.000873, 	 Training accuracy 	 96.09
# 	 Validation loss: 	 0.001328,	 Validation accuracy 	 93.86
# Test loss: 	 0.001405, 	 	 Test accuracy 	 94.01
# After training:
# 	 Training loss: 	 0.000790, 	 Training accuracy 	 96.42
# 	 Validation loss: 	 0.001372,	 Validation accuracy 	 93.76
# Test loss: 	 0.001405, 	 	 Test accuracy 	 94.01
# | Wide-Resnet 40x2
# loaded net test:
# 	 Test loss: 	 0.001405, 	 Test accuracy 	 94.01
